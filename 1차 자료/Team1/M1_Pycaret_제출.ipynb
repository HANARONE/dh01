# %% [markdown]
# # 라이브러리 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statistics

# %% [markdown]
# # 데이터 불러오기

# %%
df_clean = pd.read_csv('/content/drive/MyDrive/hana1/Team/final/train_outlier_drop2.csv', index_col = 0)
df_clean.head()
# Out:
#    Month   Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 3      4  23.0          12       19114.12            1824.843333
# 5      6  23.0          12       19114.12            1824.843333
# 6      7  23.0          12       19114.12            1824.843333
# 7      8  23.0          12       19114.12            1824.843333
# 8      1  28.0          13       34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 3                3.0              4.0            3.0          4.0
# 5                3.0              4.0            3.0          4.0
# 6                3.0              4.0            3.0          4.0
# 7                3.0              4.0            3.0          4.0
# 8                2.0              4.0            6.0          1.0
#
#    Delay_from_due_date  ...  Credit_Mix  Outstanding_Debt  \
# 3                  5.0  ...           1            809.98
# ...

# %% [markdown]
# # Pycaret

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.4/484.4 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 50.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.6 MB/s eta 0:00:00
# ...

# %%
from pycaret.classification import *

# %%
# 모델 생성
model = setup(df_clean, target = 'Credit_Score', session_id = 123)
# Out:
# <style type="text/css">
# #T_5f2e1_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5f2e1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f2e1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5f2e1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f2e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f2e1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5f2e1_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5f2e1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f2e1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5f2e1_row1_col1" class="data row1 col1" >Credit_Score</td>
#     </tr>
#     <tr>
#       <th id="T_5f2e1_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models(round = 4, sort = 'Accuracy', n_select = 1, verbose = True)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      00:52:05
# Status     . . . . . . . . . . . . . . . . . .              Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
# <style type="text/css">
# #T_1f24a th {
#   text-align: left;
# }
# ...

# %%
best_model
