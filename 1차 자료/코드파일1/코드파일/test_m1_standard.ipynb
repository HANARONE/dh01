# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statistics

# %%
df_train = pd.read_csv('/content/drive/MyDrive/hana1/project1/data/train_outlier_drop2.csv', index_col = 0)
df_test = pd.read_csv('/content/drive/MyDrive/hana1/project1/data/test_outlier_drpo2.csv', index_col = 0) # 20*28

# %%
df_train.head()
# Out:
#    Month   Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 3      4  23.0          12       19114.12            1824.843333
# 5      6  23.0          12       19114.12            1824.843333
# 6      7  23.0          12       19114.12            1824.843333
# 7      8  23.0          12       19114.12            1824.843333
# 8      1  28.0          13       34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 3                3.0              4.0            3.0          4.0
# 5                3.0              4.0            3.0          4.0
# 6                3.0              4.0            3.0          4.0
# 7                3.0              4.0            3.0          4.0
# 8                2.0              4.0            6.0          1.0
#
#    Delay_from_due_date  ...  Credit_Mix  Outstanding_Debt  \
# 3                  5.0  ...           1            809.98
# ...

# %%
df_test.head()
# Out:
#    Month   Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      9  23.0          12       19114.12            1824.843333
# 1     10  24.0          12       19114.12            1824.843333
# 2     11  24.0          12       19114.12            1824.843333
# 3     12  24.0          12       19114.12            1824.843333
# 4      9  28.0          13       34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                3.0              4.0            3.0          4.0
# 1                3.0              4.0            3.0          4.0
# 2                3.0              4.0            3.0          4.0
# 3                3.0              4.0            3.0          4.0
# 4                2.0              4.0            6.0          1.0
#
#    Delay_from_due_date  ...  Num_Credit_Inquiries  Credit_Mix  \
# 0                  3.0  ...                2022.0           1
# ...

# %%
# train 데이터와 test 데이터로 분할

#Spli Input & Output Data
X_train = df_train.drop('Credit_Score',axis=1)
y_train = df_train['Credit_Score']
X_test = df_test
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (50503, 22)
# (50503,)
# (24683, 22)

# %% [markdown]
# # model building

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score,classification_report,confusion_matrix

# %% [markdown]
# # Extra Tree

# %% [markdown]
# #### 데이터 분할

# %%
# Split Data 8:2
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42,stratify=y_train)
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (40402, 22)
# (10101, 22)
# (40402,)
# (10101,)

# %% [markdown]
# #### 모델 훈련 & 교차검증

# %%
from sklearn.model_selection import cross_validate
from sklearn.ensemble import ExtraTreesClassifier
et = ExtraTreesClassifier(n_jobs = -1, random_state=42)
scores = cross_validate(et, X_train, y_train, return_train_score=True,
                        n_jobs = -1, cv = 5)
print("5-fold : ", scores['test_score'])
# Out:
# 5-fold :  [0.80064348 0.79767356 0.80569307 0.80470297 0.80247525]

# %%
print(np.mean(scores['train_score']), np.mean(scores['test_score']))
# Out:
# 1.0 0.8022376654198027

# %% [markdown]
# #### 성능평가

# %%
et.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(n_jobs=-1, random_state=42)

# %%
y_train_pred = et.predict(X_train)
y_val_pred = et.predict(X_val)
print(y_train_pred[:5])
print(y_train.values[:5])
print(y_val_pred[:5])
print(y_val.values[:5])
# Out:
# [2 2 0 2 2]
# [2 2 0 2 2]
# [2 2 2 1 1]
# [2 2 2 1 1]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train, y_train_pred))
print(classification_report(y_val, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7445
#            1       1.00      1.00      1.00     10597
#            2       1.00      1.00      1.00     22360
#
#     accuracy                           1.00     40402
#    macro avg       1.00      1.00      1.00     40402
# weighted avg       1.00      1.00      1.00     40402
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77      1861
#            1       0.81      0.80      0.80      2650
#            2       0.83      0.84      0.84      5590
#
#     accuracy                           0.82     10101
#    macro avg       0.80      0.80      0.80     10101
# weighted avg       0.82      0.82      0.82     10101

# %%
y_pred = et.predict(X_test)
y_pred   # standard=2 빼오기
# Out:
# array([0, 2, 2, ..., 2, 2, 1])

# %% [markdown]
# # standard 빼오기

# %%
df_test['Credit_Score'] = y_pred

# %%
df_test
# Out:
#        Month   Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0          9  23.0          12       19114.12            1824.843333
# 1         10  24.0          12       19114.12            1824.843333
# 2         11  24.0          12       19114.12            1824.843333
# 3         12  24.0          12       19114.12            1824.843333
# 4          9  28.0          13       34847.84            3037.986667
# ...      ...   ...         ...            ...                    ...
# 49992      9  29.0           1       20002.88            1929.906667
# 49993     10  29.0           1       20002.88            1929.906667
# 49994     11  29.0           1       20002.88            1929.906667
# 49997     10  25.0           9       39628.99            3359.415833
# 49998     11  25.0           9       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# ...

# %%
df_test['Credit_Score'].value_counts()
# Out:
# 2    14007
# 1     6393
# 0     4283
# Name: Credit_Score, dtype: int64

# %%
df_standard = df_test[df_test['Credit_Score'] == 2]
df_standard
# Out:
#        Month   Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 1         10  24.0          12       19114.12            1824.843333
# 2         11  24.0          12       19114.12            1824.843333
# 3         12  24.0          12       19114.12            1824.843333
# 8          9  35.0           4      143162.64           12187.220000
# 9         10  35.0           4      143162.64           12187.220000
# ...      ...   ...         ...            ...                    ...
# 49975     12  33.0          10       59146.36            4908.863333
# 49992      9  29.0           1       20002.88            1929.906667
# 49993     10  29.0           1       20002.88            1929.906667
# 49994     11  29.0           1       20002.88            1929.906667
# 49997     10  25.0           9       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# ...

# %%
#drop_standard_test = df_standard.to_csv('C:\\Users\\User\\Desktop\\프로젝트1(신용평가)\\Data\\drop_standard_test.csv')
